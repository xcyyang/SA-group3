# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D as axes3d
import numpy as np
from random import randrange

# %%
label = "Binary"

# %%
df_DT = pd.read_csv(label+'_DT.csv')

# %%
print(df_DT)
# Out:
#       preprocess feature_selection  percentage_selection  depth  \
# 0    standardize               PCA                   0.1      2
# 1    standardize               PCA                   0.1      5
# 2    standardize               PCA                   0.1     10
# 3    standardize               PCA                   0.1     20
# 4    standardize               PCA                   0.1   None
# 5    standardize               PCA                   0.3      2
# 6    standardize               PCA                   0.3      5
# 7    standardize               PCA                   0.3     10
# 8    standardize               PCA                   0.3     20
# 9    standardize               PCA                   0.3   None
# 10   standardize               PCA                   0.5      2
# 11   standardize               PCA                   0.5      5
# 12   standardize               PCA                   0.5     10
# 13   standardize               PCA                   0.5     20
# 14   standardize               PCA                   0.5   None
# 15   standardize               PCA                   0.7      2
# 16   standardize               PCA                   0.7      5
# 17   standardize               PCA                   0.7     10
# 18   standardize               PCA                   0.7     20
# 19   standardize               PCA                   0.7   None
# 20   standardize               PCA                   0.8      2
# 21   standardize               PCA                   0.8      5
# 22   standardize               PCA                   0.8     10
# 23   standardize               PCA                   0.8     20
# 24   standardize               PCA                   0.8   None
# 25   standardize               PCA                   0.9      2
# 26   standardize               PCA                   0.9      5
# 27   standardize             ANOVA                   0.7     10
# 28   standardize             ANOVA                   0.7     20
# 29   standardize             ANOVA                   0.8     10
# 30   standardize             ANOVA                   0.8     20
# 31   standardize             ANOVA                   0.9     10
# 32   standardize             ANOVA                   0.9     20
#
#     f1_scores(mean)  accuracy(mean)  precision(mean)  recall(mean)  \
# 0          0.862813        0.882312         0.982035      0.769412
# 1          0.911226        0.918498         0.957269      0.869538
# 2          0.927944        0.932725         0.956746      0.901094
# 3          0.942913        0.945220         0.945336      0.940508
# 4          0.942675        0.944758         0.941091      0.944268
# 5          0.920043        0.926944         0.971422      0.873838
# 6          0.954025        0.955724         0.952092      0.956905
# 7          0.982713        0.983446         0.987266      0.978203
# 8          0.988257        0.988707         0.988673      0.987842
# 9          0.987798        0.988255         0.987335      0.988262
# 10         0.920018        0.925924         0.958261      0.885955
# 11         0.959256        0.961197         0.969746      0.949227
# 12         0.985062        0.985658         0.986976      0.983162
# 13         0.989337        0.989746         0.989734      0.988942
# 14         0.988863        0.989284         0.988745      0.988982
# 15         0.920458        0.925328         0.945320      0.898774
# 16         0.967597        0.968969         0.972192      0.963065
# 17         0.987523        0.988015         0.988936      0.986122
# 18         0.989581        0.989977         0.989603      0.989561
# 19         0.989344        0.989746         0.989088      0.989601
# 20         0.922372        0.925828         0.929627      0.916212
# 21         0.968419        0.969845         0.975993      0.960986
# 22         0.987558        0.988044         0.988662      0.986462
# 23         0.989290        0.989698         0.989422      0.989162
# 24         0.989475        0.989871         0.989170      0.989781
# 25         0.922372        0.925828         0.929627      0.916212
# 26         0.968738        0.970143         0.976049      0.961565
# 27         0.983587        0.984167         0.980871      0.986322
# 28         0.989429        0.989833         0.989657      0.989202
# 29         0.984319        0.984860         0.980784      0.987882
# 30         0.989344        0.989746         0.989146      0.989541
# 31         0.989231        0.989631         0.988343      0.990121
# 32         0.991040        0.991381         0.991160      0.990921
#
#     roc_auc(mean)
# 0        0.953517
# 1        0.977298
# 2        0.982898
# 3        0.959891
# 4        0.945244
# 5        0.933057
# 6        0.991004
# 7        0.994998
# 8        0.990798
# 9        0.988803
# 10       0.937344
# 11       0.984024
# 12       0.994534
# 13       0.990752
# 14       0.989429
# 15       0.941945
# 16       0.988417
# 17       0.992845
# 18       0.988951
# 19       0.989917
# 20       0.948638
# 21       0.988175
# 22       0.992139
# 23       0.988526
# 24       0.990014
# 25       0.948638
# 26       0.988086
# 27       0.995628
# 28       0.992012
# 29       0.995563
# 30       0.991995
# 31       0.995242
# 32       0.993261

# %%
df_DT_feature_selection = df_DT.groupby(['feature_selection'])

fig, ax = plt.subplots()
df_DT_feature_selection.get_group(' PCA').plot(kind='scatter', x='depth', y='f1_scores(mean)',
                                               s=60, c='percentage_selection', cmap='RdYlGn'
                                               ,ax=ax,title="PCA")
fig2,ax2 = plt.subplots()
df_DT_feature_selection.get_group(' ANOVA').plot(kind='scatter', x='depth', y='f1_scores(mean)',
                                               s=60, c='percentage_selection', cmap='RdYlGn'
                                               ,ax=ax2,title="ANOVA")
fig.savefig(label+"_DT"+"_PCA"+"_F1"+".png", dpi=500)
fig2.savefig(label+"_DT"+"_ANOVA"+"_F1"+".png", dpi=500)

fig3, ax3 = plt.subplots()
df_DT_feature_selection.get_group(' PCA').plot(kind='scatter', x='depth', y='roc_auc(mean)',
                                               s=60, c='percentage_selection', cmap='RdYlGn'
                                               ,ax=ax3,title="PCA")
fig4,ax4 = plt.subplots()
df_DT_feature_selection.get_group(' ANOVA').plot(kind='scatter', x='depth', y='roc_auc(mean)',
                                               s=60, c='percentage_selection', cmap='RdYlGn'
                                               ,ax=ax4,title="ANOVA")
fig3.savefig(label+"_DT"+"_PCA"+"_ROC"+".png", dpi=500)
fig4.savefig(label+"_DT"+"_ANOVA"+"_ROC"+".png", dpi=500)

# %%
df_LG = pd.read_csv(label+'_LG.csv')
df_LG_feature_selection = df_LG.groupby(['feature_selection'])

fig, ax = plt.subplots()
df_LG_feature_selection.get_group(' PCA').plot(kind='scatter', x='solver', y='f1_scores(mean)',
                                               s=60, c='percentage_selection', cmap='RdYlGn'
                                               ,ax=ax,title="PCA")
fig2,ax2 = plt.subplots()
df_LG_feature_selection.get_group(' ANOVA').plot(kind='scatter', x='solver', y='f1_scores(mean)',
                                               s=60, c='percentage_selection', cmap='RdYlGn'
                                               ,ax=ax2,title="ANOVA")
fig.savefig(label+"_LG"+"_PCA"+"_F1"+".png", dpi=500)
fig2.savefig(label+"_LG"+"_ANOVA"+"_F1"+".png", dpi=500)

fig3, ax3 = plt.subplots()
df_LG_feature_selection.get_group(' PCA').plot(kind='scatter', x='solver', y='roc_auc(mean)',
                                               s=60, c='percentage_selection', cmap='RdYlGn'
                                               ,ax=ax3,title="PCA")
fig4,ax4 = plt.subplots()
df_LG_feature_selection.get_group(' ANOVA').plot(kind='scatter', x='solver', y='roc_auc(mean)',
                                               s=60, c='percentage_selection', cmap='RdYlGn'
                                               ,ax=ax4,title="ANOVA")
fig3.savefig(label+"_LG"+"_PCA"+"_ROC"+".png", dpi=500)
fig4.savefig(label+"_LG"+"_ANOVA"+"_ROC"+".png", dpi=500)

# %%
df_SVM = pd.read_csv(label+'_SVM.csv')
df_SVM_feature_selection = df_SVM.groupby(['feature_selection'])

fig, ax = plt.subplots()
df_SVM_feature_selection.get_group(' PCA').plot(kind='scatter', x='kernel_selection', y='f1_scores(mean)',
                                               s=60, c='percentage_selection', cmap='RdYlGn'
                                               ,ax=ax,title="PCA")
fig2,ax2 = plt.subplots()
df_SVM_feature_selection.get_group(' ANOVA').plot(kind='scatter', x='kernel_selection', y='f1_scores(mean)',
                                               s=60, c='percentage_selection', cmap='RdYlGn'
                                               ,ax=ax2,title="ANOVA")
fig.savefig(label+"_SVM"+"_PCA"+"_F1"+".png", dpi=500)
fig2.savefig(label+"_SVM"+"_ANOVA"+"_F1"+".png", dpi=500)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-7dc7f271ee3b> in <module>
#       7                                                ,ax=ax,title="PCA")
#       8 fig2,ax2 = plt.subplots()
# ----> 9 df_SVM_feature_selection.get_group(' ANOVA').plot(kind='scatter', x='kernel_selection', y='f1_scores(mean)',
#      10                                                s=60, c='percentage_selection', cmap='RdYlGn'
#      11                                                ,ax=ax2,title="ANOVA")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in get_group(self, name, obj)
#     684         inds = self._get_index(name)
#     685         if not len(inds):
# --> 686             raise KeyError(name)
#     687
#     688         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: ' ANOVA'

# %%
fig, ax = plt.subplots()
percentage_selection = 0.7
df_SVM_PCA = df_SVM_feature_selection.get_group(' PCA')
df_SVM_PCA[(df_SVM_PCA['percentage_selection']==percentage_selection)].plot(kind='scatter', x='kernel_selection', y='f1_scores(mean)',
                                               s=60, c='C_selection', cmap='RdYlGn'
                                               ,ax=ax,title="PCA "+str(percentage_selection))

fig2,ax2 = plt.subplots()
df_SVM_ANOVA = df_SVM_feature_selection.get_group(' ANOVA')
df_SVM_ANOVA[(df_SVM_ANOVA['percentage_selection']==0.1)].plot(kind='scatter', x='kernel_selection', y='f1_scores(mean)',
                                               s=60, c='C_selection', cmap='RdYlGn'
                                               ,ax=ax2,title="ANOVA "+str(0.1))
fig.savefig(label+"_SVM"+"_PCA"+"_F1"+"_C_selection"+".png", dpi=500)
fig2.savefig(label+"_SVM"+"_ANOVA"+"_F1"+"_C_selection"+".png", dpi=500)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-f98a10a75bd8> in <module>
#       7
#       8 fig2,ax2 = plt.subplots()
# ----> 9 df_SVM_ANOVA = df_SVM_feature_selection.get_group(' ANOVA')
#      10 df_SVM_ANOVA[(df_SVM_ANOVA['percentage_selection']==0.1)].plot(kind='scatter', x='kernel_selection', y='f1_scores(mean)',
#      11                                                s=60, c='C_selection', cmap='RdYlGn'
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in get_group(self, name, obj)
#     684         inds = self._get_index(name)
#     685         if not len(inds):
# --> 686             raise KeyError(name)
#     687
#     688         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: ' ANOVA'
