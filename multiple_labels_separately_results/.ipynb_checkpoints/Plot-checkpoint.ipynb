# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D as axes3d
import numpy as np
from random import randrange

# %%
label = "DoS"

# %%
df_DT = pd.read_csv(label+'_DT.csv')

# %%
print(df_DT)
# Out:
#       preprocess feature_selection  percentage_selection  depth  \
# 0    standardize               PCA                   0.1      2
# 1    standardize               PCA                   0.1      5
# 2    standardize               PCA                   0.1     10
# 3    standardize               PCA                   0.1     20
# 4    standardize               PCA                   0.1   None
# 5    standardize               PCA                   0.3      2
# 6    standardize               PCA                   0.3      5
# 7    standardize               PCA                   0.3     10
# 8    standardize               PCA                   0.3     20
# 9    standardize               PCA                   0.3   None
# 10   standardize               PCA                   0.5      2
# 11   standardize               PCA                   0.5      5
# 12   standardize               PCA                   0.5     10
# 13   standardize               PCA                   0.5     20
# ...

# %%
# df_DT.plot(x="depth",y=["f1_scores(mean)"])
df_DT_by_feature_selection = df_DT.groupby("feature_selection")
df_DT['preprocess'] =df_DT['preprocess'].astype('|S')
df_DT['feature_selection'] =df_DT['feature_selection'].astype('|S')
df_DT['depth'] =df_DT['depth'].astype('|S')
df_DT.info()
# df_DT.boxplot(column='depth',by='feature_selection')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   preprocess            60 non-null     |S12
#  1   feature_selection     60 non-null     object
#  2   percentage_selection  60 non-null     float64
#  3   depth                 60 non-null     object
#  4   f1_scores(mean)       60 non-null     float64
#  5   accuracy(mean)        60 non-null     float64
#  6   precision(mean)       60 non-null     float64
#  7   recall(mean)          60 non-null     float64
#  8   roc_auc(mean)         60 non-null     float64
# dtypes: bytes96(1), float64(6), object(2)
# memory usage: 4.6+ KB
