# %% [markdown]
# # Multiple labels (separately)
# ## Load Datasets

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
col_names = ["duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate","label", "difficulty_level"]

df_train_multiple_labels = pd.read_csv("KDDTrain+.txt", header=None, names = col_names)
df_test_multiple_labels = pd.read_csv("KDDTest+.txt", header=None, names = col_names)

print(df_train_multiple_labels.shape)
print(df_test_multiple_labels.shape)
print(df_train_multiple_labels.head(1))
# Out:
# (125973, 43)
# (22544, 43)
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                          0.0                   0.0
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                       0.0                  0.05                       0.0
#
#     label  difficulty_level
# 0  normal                20
#
# [1 rows x 43 columns]

# %%
df_train_multiple_labels.describe()
# Out:
#            duration     src_bytes     dst_bytes           land  \
# count  125973.00000  1.259730e+05  1.259730e+05  125973.000000
# mean      287.14465  4.556674e+04  1.977911e+04       0.000198
# std      2604.51531  5.870331e+06  4.021269e+06       0.014086
# min         0.00000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.00000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.00000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.00000  2.760000e+02  5.160000e+02       0.000000
# max     42908.00000  1.379964e+09  1.309937e+09       1.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125973.000000  125973.000000  125973.000000      125973.000000
# mean         0.022687       0.000111       0.204409           0.001222
# std          0.253530       0.014366       2.149968           0.045239
# min          0.000000       0.000000       0.000000           0.000000
# 25%          0.000000       0.000000       0.000000           0.000000
# 50%          0.000000       0.000000       0.000000           0.000000
# 75%          0.000000       0.000000       0.000000           0.000000
# max          3.000000       3.000000      77.000000           5.000000
#
#            logged_in  num_compromised  ...  dst_host_srv_count  \
# count  125973.000000    125973.000000  ...       125973.000000
# mean        0.395736         0.279250  ...          115.653005
# std         0.489010        23.942042  ...          110.702741
# min         0.000000         0.000000  ...            0.000000
# 25%         0.000000         0.000000  ...           10.000000
# 50%         0.000000         0.000000  ...           63.000000
# 75%         1.000000         0.000000  ...          255.000000
# max         1.000000      7479.000000  ...          255.000000
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# count           125973.000000           125973.000000
# mean                 0.521242                0.082951
# std                  0.448949                0.188922
# min                  0.000000                0.000000
# 25%                  0.050000                0.000000
# 50%                  0.510000                0.020000
# 75%                  1.000000                0.070000
# max                  1.000000                1.000000
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# count                125973.000000                125973.000000
# mean                      0.148379                     0.032542
# std                       0.308997                     0.112564
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.060000                     0.020000
# max                       1.000000                     1.000000
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count         125973.000000             125973.000000         125973.000000
# mean               0.284452                  0.278485              0.118832
# std                0.444784                  0.445669              0.306557
# min                0.000000                  0.000000              0.000000
# 25%                0.000000                  0.000000              0.000000
# 50%                0.000000                  0.000000              0.000000
# 75%                1.000000                  1.000000              0.000000
# max                1.000000                  1.000000              1.000000
#
#        dst_host_srv_rerror_rate  difficulty_level
# count             125973.000000     125973.000000
# mean                   0.120240         19.504060
# std                    0.319459          2.291503
# min                    0.000000          0.000000
# 25%                    0.000000         18.000000
# 50%                    0.000000         20.000000
# 75%                    0.000000         21.000000
# max                    1.000000         21.000000
#
# [8 rows x 39 columns]

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

pd.set_option('display.max_columns', None)

# %%
# Combine training dataset with testing dataset to apply One-Hot-Encoder
df_multiple_labels = pd.concat([df_train_multiple_labels, df_test_multiple_labels], ignore_index=True)
# Drop "difficulty_level"
df_multiple_labels = df_multiple_labels.drop("difficulty_level", axis=1)
# One-Hot-Encoder for "protocol_type","service","flag"
categorical_col = ["protocol_type","service","flag"]
for col in categorical_col:
    df_dummies = pd.get_dummies(df_multiple_labels[col], prefix=col+"_")
    df_multiple_labels = df_multiple_labels.drop(col, axis=1)
    df_multiple_labels = pd.concat([df_multiple_labels,df_dummies], axis=1)
# LabelEncoder for "labels"
# Five Labels: normal: 0, DoS: 1, Probe: 2, R2L:3, U2R: 4
df_multiple_labels = df_multiple_labels.replace({'label':{'normal' : 0, 'neptune' : 1 ,'back': 1, 'land': 1, 'pod': 1, 'smurf': 1, 'teardrop': 1,'mailbomb': 1, 'apache2': 1, 'processtable': 1, 'udpstorm': 1, 'worm': 1,
                           'ipsweep' : 2,'nmap' : 2,'portsweep' : 2,'satan' : 2,'mscan' : 2,'saint' : 2
                           ,'ftp_write': 3,'guess_passwd': 3,'imap': 3,'multihop': 3,'phf': 3,'spy': 3,'warezclient': 3,'warezmaster': 3,'sendmail': 3,'named': 3,'snmpgetattack': 3,'snmpguess': 3,'xlock': 3,'xsnoop': 3,'httptunnel': 3,
                           'buffer_overflow': 4,'loadmodule': 4,'perl': 4,'rootkit': 4,'ps': 4,'sqlattack': 4,'xterm': 4}})
# print(df_multiple_labels.head(1))
df_multiple_labels_normal = df_multiple_labels.loc[df_multiple_labels["label"]==0]
df_multiple_labels_DoS = df_multiple_labels.loc[df_multiple_labels["label"]==1]
df_multiple_labels_Probe = df_multiple_labels.loc[df_multiple_labels["label"]==2]
df_multiple_labels_R2L = df_multiple_labels.loc[df_multiple_labels["label"]==3]
df_multiple_labels_U2R = df_multiple_labels.loc[df_multiple_labels["label"]==4]
print(df_multiple_labels_normal.shape)
print(df_multiple_labels_DoS.shape)
print(df_multiple_labels_Probe.shape)
print(df_multiple_labels_R2L.shape)
print(df_multiple_labels_U2R.shape)
# Out:
# (77054, 123)
# (53387, 123)
# (14077, 123)
# (3880, 123)
# (119, 123)

# %%
## DoS Dataset
df_DoS_normal = pd.concat([df_multiple_labels_normal, df_multiple_labels_DoS], ignore_index=True)
df_DoS_normal['label'] = np.where(df_DoS_normal['label'].eq(1), 1, 0)
## Probe Dataset
df_Probe_normal = pd.concat([df_multiple_labels_normal, df_multiple_labels_Probe], ignore_index=True)
df_Probe_normal['label'] = np.where(df_Probe_normal['label'].eq(2), 1, 0)
## R2L Dataset
df_R2L_normal = pd.concat([df_multiple_labels_normal, df_multiple_labels_R2L], ignore_index=True)
df_R2L_normal['label'] = np.where(df_R2L_normal['label'].eq(3), 1, 0)
## U2R Dataset
df_U2R_normal = pd.concat([df_multiple_labels_normal, df_multiple_labels_U2R], ignore_index=True)
df_U2R_normal['label'] = np.where(df_U2R_normal['label'].eq(4), 1, 0)

print(df_DoS_normal.shape)
print(df_Probe_normal.shape)
print(df_R2L_normal.shape)
print(df_U2R_normal.shape)
# Out:
# (130441, 123)
# (91131, 123)
# (80934, 123)
# (77173, 123)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score, roc_curve, recall_score, precision_score,f1_score 

from sklearn.preprocessing import StandardScaler,Normalizer

from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectPercentile, f_classif

from sklearn.model_selection import KFold, cross_val_score, cross_validate
from sklearn.pipeline import make_pipeline, Pipeline

from sklearn.tree import DecisionTreeClassifier

# %%
def printResults(results):
    #print(results.keys())
    print("f1_scores(mean): ", sum(results['test_f1'])/len(results['test_f1']))
    print("accuracy(mean): ", sum(results['test_accuracy'])/len(results['test_accuracy']))
    print("precision(mean): ", sum(results['test_precision'])/len(results['test_precision']))
    print("recall(mean): ", sum(results['test_recall'])/len(results['test_recall']))
    print("roc_auc(mean): ", sum(results['test_roc_auc'])/len(results['test_roc_auc']))

def generate_preprocess_pipeline(preprocess):
    if preprocess == "standardize":
        return StandardScaler()
    elif preprocess == "normalize":
        return Normalizer()
    
def generate_feature_selection_pipeline(feature_selection, percentage):
    if feature_selection == "PCA":
        return PCA(n_components = percentage)
    elif feature_selection == "ANOVA":
        return SelectPercentile(f_classif, percentile=(percentage*100))
                                
def DT(X,y):
    preprocess_methods = ["standardize"]
    
    feature_selection_methods = ["PCA","ANOVA"]
    percentage_selections = [0.1,0.3,0.5,0.7,0.8,0.9]
  
    DT_depth_selections= [2,5,10,20,None]
    
    for preprocess_method in preprocess_methods:
        preprocess_pipeline = generate_preprocess_pipeline(preprocess_method)
        for feature_selection_method in feature_selection_methods:
            for percentage_selection in percentage_selections:
                feature_selection_pipeline = generate_feature_selection_pipeline(feature_selection_method, percentage_selection)
                for DT_depth in DT_depth_selections:
                    complete_pipline = Pipeline([
                         ('preprocess',preprocess_pipeline ),
                         ('feature_selection',feature_selection_pipeline),
                        ('estimator',DecisionTreeClassifier(max_depth=DT_depth,random_state=0))
                    ])
                    results = cross_validate(complete_pipline, X, y, cv=5,
                         scoring=('f1', 'accuracy', 'precision','recall','roc_auc'), return_estimator=True)
                    print("preprocess: ",preprocess_method)
                    print("feature_selection: ", feature_selection_method)
                    print("percentage_selection: ", percentage_selection)
                    print("depth: ", DT_depth)
                    printResults(results)
                    print("-------------------------------------------------------------------------------------")

# %%
from sklearn.linear_model import LogisticRegression
def LG(X,y):
    preprocess_methods = ["standardize"]
    
    feature_selection_methods = ["PCA","ANOVA"]
    percentage_selections = [0.1,0.3,0.5,0.7,0.8,0.9]
  
    LG_solvers= ['newton-cg','lbfgs','sag']
    
    for preprocess_method in preprocess_methods:
        preprocess_pipeline = generate_preprocess_pipeline(preprocess_method)
        for feature_selection_method in feature_selection_methods:
            for percentage_selection in percentage_selections:
                feature_selection_pipeline = generate_feature_selection_pipeline(feature_selection_method, percentage_selection)
                for LG_solver in LG_solvers:
                    complete_pipline = Pipeline([
                         ('preprocess',preprocess_pipeline ),
                         ('feature_selection',feature_selection_pipeline),
                        ('estimator',LogisticRegression(solver = LG_solver,max_iter=100))
                    ])
                    results = cross_validate(complete_pipline, X, y, cv=5,
                         scoring=('f1', 'accuracy', 'precision','recall','roc_auc'), return_estimator=True)
                    print("preprocess: ",preprocess_method)
                    print("feature_selection: ", feature_selection_method)
                    print("percentage_selection: ", percentage_selection)
                    print("solver: ", LG_solver)
                    printResults(results)
                    print("-------------------------------------------------------------------------------------")

# %%
from sklearn.svm import SVC
def SVM(X,y):
    preprocess_methods = ["standardize"]
    
#     feature_selection_methods = ["PCA","ANOVA"]
    feature_selection_methods = ["ANOVA"]
#     percentage_selections = [0.7,0.8,0.9]
    percentage_selections = [0.1,0.3,0.5]
  
    C_selections = [0.2,0.5,1,2,5]
    kernel_selections = ['poly','rbf','sigmoid']
    for preprocess_method in preprocess_methods:
        preprocess_pipeline = generate_preprocess_pipeline(preprocess_method)
        for feature_selection_method in feature_selection_methods:
            for percentage_selection in percentage_selections:
                feature_selection_pipeline = generate_feature_selection_pipeline(feature_selection_method, percentage_selection)
                for  C_selection in  C_selections:
                    for kernel_selection in kernel_selections:
                        complete_pipline = Pipeline([
                         ('preprocess',preprocess_pipeline ),
                         ('feature_selection',feature_selection_pipeline),
                        ('estimator',SVC(C=C_selection, kernel=kernel_selection,verbose = True))
                    ])
                        results = cross_validate(complete_pipline, X, y, cv=5,
                         scoring=('f1', 'accuracy', 'precision','recall','roc_auc'), return_estimator=True)
                        print("preprocess: ",preprocess_method)
                        print("feature_selection: ", feature_selection_method)
                        print("percentage_selection: ", percentage_selection)
                        print("C_selection: ", C_selection)
                        print("kernel_selection: ", kernel_selection)
                        printResults(results)
                        print("-------------------------------------------------------------------------------------")

# %%
## Split dataset to training set and testing set
from sklearn.model_selection import train_test_split
def splitDataset(df):
    X = df.drop(columns=['label'])
    y = df['label']
    print(X.shape)
    print(y.shape)

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size = 0.3, random_state=6)
    print(X_train.shape)
    print(y_train)
    print(X_test.shape)
    print(y_test)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## DoS
# ### Split Dataset

# %%
X_train, X_test, y_train, y_test = splitDataset(df_DoS_normal)
# Out:
# (130441, 122)
# (130441,)
# (91308, 122)
# 94026     1
# 92878     1
# 87480     1
# 23792     0
# 19098     0
#          ..
# 4714      0
# 108500    1
# 41187     0
# 117449    1
# 31626     0
# Name: label, Length: 91308, dtype: int32
# (39133, 122)
# 46256     0
# 34191     0
# 119153    1
# 113313    1
# 103582    1
#          ..
# 109454    1
# 55651     0
# 7815      0
# 77071     1
# 115381    1
# Name: label, Length: 39133, dtype: int32

# %% [markdown]
# ### Decision Tree

# %%
DT(X_train,y_train)
# Out:
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.1
# depth:  2
# f1_scores(mean):  0.937979980338737
# accuracy(mean):  0.9515814973397905
# precision(mean):  0.9855290488982484
# recall(mean):  0.8948185881736709
# roc_auc(mean):  0.9463707340361605
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.1
# depth:  5
# f1_scores(mean):  0.9455673715663266
# accuracy(mean):  0.9571669828123033
# precision(mean):  0.9851604321691132
# recall(mean):  0.9090837435896996
# roc_auc(mean):  0.9830549469560725
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.1
# depth:  10
# f1_scores(mean):  0.9660142151535901
# accuracy(mean):  0.972532550160326
# precision(mean):  0.9783012517912753
# recall(mean):  0.9540468563344815
# roc_auc(mean):  0.9924037233040803
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.1
# depth:  20
# f1_scores(mean):  0.9690863879400873
# accuracy(mean):  0.9747010227364875
# precision(mean):  0.9691168504552168
# recall(mean):  0.9690610860052649
# roc_auc(mean):  0.975795884251764
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.1
# depth:  None
# f1_scores(mean):  0.9685557153741489
# accuracy(mean):  0.9742519897198048
# precision(mean):  0.9680521310481014
# recall(mean):  0.9690611218230025
# roc_auc(mean):  0.9735409144577988
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.3
# depth:  2
# f1_scores(mean):  0.9561365547010953
# accuracy(mean):  0.9652933119567317
# precision(mean):  0.9902169344729963
# recall(mean):  0.9243388690363108
# roc_auc(mean):  0.9613535754493923
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.3
# depth:  5
# f1_scores(mean):  0.9750391093536092
# accuracy(mean):  0.9799140567491808
# precision(mean):  0.991351998093708
# recall(mean):  0.9593728392949809
# roc_auc(mean):  0.9918266005291304
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.3
# depth:  10
# f1_scores(mean):  0.9953789013942405
# accuracy(mean):  0.9962215677108842
# precision(mean):  0.9962753823362647
# recall(mean):  0.9944866258000609
# roc_auc(mean):  0.9979487034760707
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.3
# depth:  20
# f1_scores(mean):  0.9967089621296763
# accuracy(mean):  0.9973058180926632
# precision(mean):  0.9964969606892549
# recall(mean):  0.9969221782284892
# roc_auc(mean):  0.9973734636016666
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.3
# depth:  None
# f1_scores(mean):  0.9966683524246942
# accuracy(mean):  0.9972729629836937
# precision(mean):  0.9965765928160193
# recall(mean):  0.9967616001473971
# roc_auc(mean):  0.997323767757285
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.5
# depth:  2
# f1_scores(mean):  0.9559589749539175
# accuracy(mean):  0.9649866450815983
# precision(mean):  0.9852214776858069
# recall(mean):  0.9285144543196335
# roc_auc(mean):  0.9631019197231163
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.5
# depth:  5
# f1_scores(mean):  0.9810488818726665
# accuracy(mean):  0.9846563168665383
# precision(mean):  0.9923449312529865
# recall(mean):  0.9701583838864881
# roc_auc(mean):  0.9922147571192417
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.5
# depth:  10
# f1_scores(mean):  0.9954897755100683
# accuracy(mean):  0.9963092041246124
# precision(mean):  0.9955352579649264
# recall(mean):  0.9954501551767663
# roc_auc(mean):  0.9974423845075575
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.5
# depth:  20
# f1_scores(mean):  0.9970160295437912
# accuracy(mean):  0.9975577138584791
# precision(mean):  0.9969767817566808
# recall(mean):  0.997055989714292
# roc_auc(mean):  0.997596632607592
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.5
# depth:  None
# f1_scores(mean):  0.9969494126457595
# accuracy(mean):  0.9975029523448707
# precision(mean):  0.9968437526130847
# recall(mean):  0.997055989714292
# roc_auc(mean):  0.9975503101973648
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# depth:  2
# f1_scores(mean):  0.9568545437963196
# accuracy(mean):  0.9650085712773876
# precision(mean):  0.966772805419916
# recall(mean):  0.9477034705381916
# roc_auc(mean):  0.9717749907464576
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# depth:  5
# f1_scores(mean):  0.9847655256350833
# accuracy(mean):  0.987580417966428
# precision(mean):  0.9889999108989223
# recall(mean):  0.9806494851844942
# roc_auc(mean):  0.9946862882447917
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# depth:  10
# f1_scores(mean):  0.9958687660560728
# accuracy(mean):  0.996615845211277
# precision(mean):  0.9953295196768774
# recall(mean):  0.9964136666446028
# roc_auc(mean):  0.9974079447283849
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# depth:  20
# f1_scores(mean):  0.9968691323863513
# accuracy(mean):  0.9974372439261273
# precision(mean):  0.9967636354933026
# recall(mean):  0.9969757042555198
# roc_auc(mean):  0.9974957299028555
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# depth:  None
# f1_scores(mean):  0.9968691323863513
# accuracy(mean):  0.9974372439261273
# precision(mean):  0.9967636354933026
# recall(mean):  0.9969757042555198
# roc_auc(mean):  0.9974957299028555
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# depth:  2
# f1_scores(mean):  0.9584850372050356
# accuracy(mean):  0.9662461814849337
# precision(mean):  0.9658184403298933
# recall(mean):  0.9517987596174207
# roc_auc(mean):  0.9737694804350789
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# depth:  5
# f1_scores(mean):  0.985880233982679
# accuracy(mean):  0.9884346837848843
# precision(mean):  0.9860804921529439
# recall(mean):  0.9857081997689898
# roc_auc(mean):  0.995589462980029
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# depth:  10
# f1_scores(mean):  0.996415075288418
# accuracy(mean):  0.9970648782279599
# precision(mean):  0.9962055390516925
# recall(mean):  0.9966277707527255
# roc_auc(mean):  0.9976911302716257
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# depth:  20
# f1_scores(mean):  0.9969101244136777
# accuracy(mean):  0.9974701050324152
# precision(mean):  0.9965245974725327
# recall(mean):  0.9972968747447986
# roc_auc(mean):  0.9975953401029287
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# depth:  None
# f1_scores(mean):  0.9969636037655544
# accuracy(mean):  0.9975139142433017
# precision(mean):  0.9966048857850414
# recall(mean):  0.9973236413400877
# roc_auc(mean):  0.9976006768852443
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# depth:  2
# f1_scores(mean):  0.9607903789676662
# accuracy(mean):  0.9681736878081914
# precision(mean):  0.9687956219633971
# recall(mean):  0.9530566212526408
# roc_auc(mean):  0.9745947269766836
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# depth:  5
# f1_scores(mean):  0.9865649009747036
# accuracy(mean):  0.9890480229327376
# precision(mean):  0.9902982977938184
# recall(mean):  0.9829248427816226
# roc_auc(mean):  0.9959856921206125
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# depth:  10
# f1_scores(mean):  0.9962543445994487
# accuracy(mean):  0.9969334589915457
# precision(mean):  0.9961800860973036
# recall(mean):  0.9963333704405095
# roc_auc(mean):  0.9977701204215226
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# depth:  20
# f1_scores(mean):  0.9970165847151449
# accuracy(mean):  0.9975577186563337
# precision(mean):  0.9967637731372327
# recall(mean):  0.9972701117312832
# roc_auc(mean):  0.9976306809492577
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# depth:  None
# f1_scores(mean):  0.9970168313951625
# accuracy(mean):  0.9975577186563337
# precision(mean):  0.9966842871452208
# recall(mean):  0.9973504115171504
# roc_auc(mean):  0.9976418984078357
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# depth:  2
# f1_scores(mean):  0.9295120483628274
# accuracy(mean):  0.9455031546464125
# precision(mean):  0.9873308836294397
# recall(mean):  0.8780912176053637
# roc_auc(mean):  0.9387018460131745
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# depth:  5
# f1_scores(mean):  0.9579461167531761
# accuracy(mean):  0.9667280060390115
# precision(mean):  0.9920858127710861
# recall(mean):  0.9260785580409244
# roc_auc(mean):  0.9782197672893884
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# depth:  10
# f1_scores(mean):  0.9684963368377291
# accuracy(mean):  0.9746134079131054
# precision(mean):  0.9838753965270257
# recall(mean):  0.9535917060160332
# roc_auc(mean):  0.9943320135056709
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# depth:  20
# f1_scores(mean):  0.9736136233096835
# accuracy(mean):  0.978588966058183
# precision(mean):  0.9820583274825326
# recall(mean):  0.9653142390407036
# roc_auc(mean):  0.9882359641842815
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# depth:  None
# f1_scores(mean):  0.9728786111118211
# accuracy(mean):  0.9780085096069632
# precision(mean):  0.9820326560690171
# recall(mean):  0.9638957599248803
# roc_auc(mean):  0.9857189790611018
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# depth:  2
# f1_scores(mean):  0.9479865990461318
# accuracy(mean):  0.9593244928903021
# precision(mean):  0.9942429106304962
# recall(mean):  0.9058451718119562
# roc_auc(mean):  0.9525795165111545
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# depth:  5
# f1_scores(mean):  0.976269669624408
# accuracy(mean):  0.9809874327933763
# precision(mean):  0.9976536071292346
# recall(mean):  0.9557862480518733
# roc_auc(mean):  0.9964313661058755
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# depth:  10
# f1_scores(mean):  0.9944326933200369
# accuracy(mean):  0.995443983604507
# precision(mean):  0.9945131845461482
# recall(mean):  0.9943528537137694
# roc_auc(mean):  0.9988592985489324
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# depth:  20
# f1_scores(mean):  0.9964001348328516
# accuracy(mean):  0.9970539211273837
# precision(mean):  0.9964406450011598
# recall(mean):  0.9963601549446673
# roc_auc(mean):  0.9972762468062747
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# depth:  None
# f1_scores(mean):  0.9963996652463931
# accuracy(mean):  0.9970539205276518
# precision(mean):  0.9965737573839359
# recall(mean):  0.9962263219682219
# roc_auc(mean):  0.9971614802748571
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# depth:  2
# f1_scores(mean):  0.9479865990461318
# accuracy(mean):  0.9593244928903021
# precision(mean):  0.9942429106304962
# recall(mean):  0.9058451718119562
# roc_auc(mean):  0.9525795165111545
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# depth:  5
# f1_scores(mean):  0.9762830253726312
# accuracy(mean):  0.9809983844963661
# precision(mean):  0.9976815010721637
# recall(mean):  0.9557862480518733
# roc_auc(mean):  0.9964409386769345
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# depth:  10
# f1_scores(mean):  0.9943936091895045
# accuracy(mean):  0.9954111284955378
# precision(mean):  0.9943014298701144
# recall(mean):  0.9944866866902148
# roc_auc(mean):  0.9988683796880522
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# depth:  20
# f1_scores(mean):  0.9964671143290813
# accuracy(mean):  0.9971086784428689
# precision(mean):  0.9964411219408544
# recall(mean):  0.9964939807575652
# roc_auc(mean):  0.9974017767447961
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# depth:  None
# f1_scores(mean):  0.9963601273300589
# accuracy(mean):  0.9970210630197549
# precision(mean):  0.9963338434637562
# recall(mean):  0.9963869143764089
# roc_auc(mean):  0.9971851669811125
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.7
# depth:  2
# f1_scores(mean):  0.9479865990461318
# accuracy(mean):  0.9593244928903021
# precision(mean):  0.9942429106304962
# recall(mean):  0.9058451718119562
# roc_auc(mean):  0.9525795165111545
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.7
# depth:  5
# f1_scores(mean):  0.9764650985053253
# accuracy(mean):  0.9811407602336246
# precision(mean):  0.9976821407196464
# recall(mean):  0.9561341851364412
# roc_auc(mean):  0.9898840211219463
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.7
# depth:  10
# f1_scores(mean):  0.9968581995338542
# accuracy(mean):  0.997426294022333
# precision(mean):  0.9960502258787753
# recall(mean):  0.9976715855882032
# roc_auc(mean):  0.998798060209268
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.7
# depth:  20
# f1_scores(mean):  0.9981935421783475
# accuracy(mean):  0.9985214877108559
# precision(mean):  0.9981535631026095
# recall(mean):  0.9982336017084774
# roc_auc(mean):  0.9986293680704922
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.7
# depth:  None
# f1_scores(mean):  0.9981935421783475
# accuracy(mean):  0.9985214877108559
# precision(mean):  0.9981535631026095
# recall(mean):  0.9982336017084774
# roc_auc(mean):  0.9986160064102407
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.8
# depth:  2
# f1_scores(mean):  0.9505433044452763
# accuracy(mean):  0.9611972341015604
# precision(mean):  0.9924706258555069
# recall(mean):  0.9121612430015722
# roc_auc(mean):  0.9552902905291824
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.8
# depth:  5
# f1_scores(mean):  0.9801932824045168
# accuracy(mean):  0.984119624046586
# precision(mean):  0.9980304798666275
# recall(mean):  0.963092565068651
# roc_auc(mean):  0.9918240571791357
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.8
# depth:  10
# f1_scores(mean):  0.9976179413994413
# accuracy(mean):  0.9980505482895345
# precision(mean):  0.9976459027054527
# recall(mean):  0.997591285802336
# roc_auc(mean):  0.9989074163637325
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.8
# depth:  20
# f1_scores(mean):  0.9982336428547903
# accuracy(mean):  0.9985543428198254
# precision(mean):  0.9982070031748778
# recall(mean):  0.9982603647219929
# roc_auc(mean):  0.9986612983871538
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.8
# depth:  None
# f1_scores(mean):  0.9982336428547903
# accuracy(mean):  0.9985543428198254
# precision(mean):  0.9982070031748778
# recall(mean):  0.9982603647219929
# roc_auc(mean):  0.9986746637686252
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.9
# depth:  2
# f1_scores(mean):  0.9576283016074928
# accuracy(mean):  0.9663118653146722
# precision(mean):  0.9855100618728649
# recall(mean):  0.9314582461171425
# roc_auc(mean):  0.9632735972570414
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.9
# depth:  5
# f1_scores(mean):  0.994463796991232
# accuracy(mean):  0.9954878144057396
# precision(mean):  0.9983821481578776
# recall(mean):  0.990579207917955
# roc_auc(mean):  0.9975697842768627
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.9
# depth:  10
# f1_scores(mean):  0.9987022327740686
# accuracy(mean):  0.9989376650188374
# precision(mean):  0.9985020224629604
# recall(mean):  0.9989027021187769
# roc_auc(mean):  0.9991281375222572
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.9
# depth:  20
# f1_scores(mean):  0.9985680363440765
# accuracy(mean):  0.9988281443905483
# precision(mean):  0.9986349642571625
# recall(mean):  0.9985012461707257
# roc_auc(mean):  0.9989342094545138
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.9
# depth:  None
# f1_scores(mean):  0.9985680363440765
# accuracy(mean):  0.9988281443905483
# precision(mean):  0.9986349642571625
# recall(mean):  0.9985012461707257
# roc_auc(mean):  0.9989342094545138
# -------------------------------------------------------------------------------------

# %%
# standardize ANOVA 0.9 10
final_pipline = Pipeline([
                         ('preprocess',StandardScaler()),
                         ('feature_selection',SelectPercentile(f_classif, percentile=90)),
                        ('estimator',DecisionTreeClassifier(max_depth=10,random_state=0))
                    ])
final_pipline.fit(X_train,y_train)
y_test_pred = final_pipline.predict(X_test)

print(accuracy_score(y_test,y_test_pred))
print(recall_score(y_test,y_test_pred))
print(precision_score(y_test,y_test_pred))
print(roc_auc_score(y_test,y_test_pred))
print(f1_score(y_test,y_test_pred))
cnf_matrix = confusion_matrix(y_test, y_test_pred)
print("tn, fp, fn, tp:",  cnf_matrix.ravel())
# Out:
# 0.9987223059821634
# 0.9985021531548399
# 0.998377535101404
# 0.9986885495328506
# 0.9984398402396406
# tn, fp, fn, tp: [23084    26    24 15999]

# %% [markdown]
# ### Logistic Regression

# %%
LG(X_train,y_train)
# Out:
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.1
# solver:  newton-cg
# f1_scores(mean):  0.9193610678097203
# accuracy(mean):  0.9373549071027087
# precision(mean):  0.971291144320028
# recall(mean):  0.8727117945804037
# roc_auc(mean):  0.9660898787827504
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.1
# solver:  lbfgs
# f1_scores(mean):  0.9193610678097203
# accuracy(mean):  0.9373549071027087
# precision(mean):  0.971291144320028
# recall(mean):  0.8727117945804037
# roc_auc(mean):  0.9660898738215838
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.1
# solver:  sag
# f1_scores(mean):  0.9193610678097203
# accuracy(mean):  0.9373549071027087
# precision(mean):  0.971291144320028
# recall(mean):  0.8727117945804037
# roc_auc(mean):  0.9660902161618019
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.3
# solver:  newton-cg
# f1_scores(mean):  0.9551844743429625
# accuracy(mean):  0.9641981026751812
# precision(mean):  0.9791498420308906
# recall(mean):  0.9323680381421655
# roc_auc(mean):  0.9826045793935789
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.3
# solver:  lbfgs
# f1_scores(mean):  0.9551844743429625
# accuracy(mean):  0.9641981026751812
# precision(mean):  0.9791498420308906
# recall(mean):  0.9323680381421655
# roc_auc(mean):  0.9826045719497852
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.3
# solver:  sag
# f1_scores(mean):  0.9552524472617456
# accuracy(mean):  0.964252862389594
# precision(mean):  0.9792335059864946
# recall(mean):  0.9324215641691961
# roc_auc(mean):  0.982619054127964
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.5
# solver:  newton-cg
# f1_scores(mean):  0.9736746375779571
# accuracy(mean):  0.9786984650961262
# precision(mean):  0.9849439037745163
# recall(mean):  0.962664593249474
# roc_auc(mean):  0.9923057766875069
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.5
# solver:  lbfgs
# f1_scores(mean):  0.9736746375779571
# accuracy(mean):  0.9786984650961262
# precision(mean):  0.9849439037745163
# recall(mean):  0.962664593249474
# roc_auc(mean):  0.9923057196338606
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.5
# solver:  sag
# f1_scores(mean):  0.9737752986650511
# accuracy(mean):  0.9787860769208491
# precision(mean):  0.9853467648185242
# recall(mean):  0.9624772378277717
# roc_auc(mean):  0.9922406763071633
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# solver:  newton-cg
# f1_scores(mean):  0.974112265969975
# accuracy(mean):  0.9790489267885822
# precision(mean):  0.9851962187263178
# recall(mean):  0.9632801533056476
# roc_auc(mean):  0.992280831499716
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# solver:  lbfgs
# f1_scores(mean):  0.974112265969975
# accuracy(mean):  0.9790489267885822
# precision(mean):  0.9851962187263178
# recall(mean):  0.9632801533056476
# roc_auc(mean):  0.9922808488621137
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# solver:  sag
# f1_scores(mean):  0.9739661144553324
# accuracy(mean):  0.9789394037613658
# precision(mean):  0.9854857171145378
# recall(mean):  0.9627181085311832
# roc_auc(mean):  0.9922127246202166
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# solver:  newton-cg
# f1_scores(mean):  0.9744651021052441
# accuracy(mean):  0.9793336794625629
# precision(mean):  0.985527798219118
# recall(mean):  0.9636548605672786
# roc_auc(mean):  0.9923312884722139
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# solver:  lbfgs
# f1_scores(mean):  0.9744651021052441
# accuracy(mean):  0.9793336794625629
# precision(mean):  0.985527798219118
# recall(mean):  0.9636548605672786
# roc_auc(mean):  0.9923312686244818
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# solver:  sag
# f1_scores(mean):  0.9739515997334337
# accuracy(mean):  0.9789284502591803
# precision(mean):  0.9855123753422739
# recall(mean):  0.962664578922379
# roc_auc(mean):  0.992241035367044
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# solver:  newton-cg
# f1_scores(mean):  0.9763039625776091
# accuracy(mean):  0.9808341053531278
# precision(mean):  0.9879990528681939
# recall(mean):  0.9648860129155896
# roc_auc(mean):  0.9923330819670306
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# solver:  lbfgs
# f1_scores(mean):  0.9763165553476313
# accuracy(mean):  0.9808450582555812
# precision(mean):  0.9880528472402015
# recall(mean):  0.9648592499020744
# roc_auc(mean):  0.9923339760026263
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# solver:  sag
# f1_scores(mean):  0.9753585852172201
# accuracy(mean):  0.9800674699510813
# precision(mean):  0.9869349627170891
# recall(mean):  0.9640563415877459
# roc_auc(mean):  0.992367061398137
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# solver:  newton-cg
# f1_scores(mean):  0.940646248180912
# accuracy(mean):  0.9528847589915561
# precision(mean):  0.9706975575504788
# recall(mean):  0.9124023214478619
# roc_auc(mean):  0.9837588850327477
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# solver:  lbfgs
# f1_scores(mean):  0.940646248180912
# accuracy(mean):  0.9528847589915561
# precision(mean):  0.9706975575504788
# recall(mean):  0.9124023214478619
# roc_auc(mean):  0.9837589817920722
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# solver:  sag
# f1_scores(mean):  0.940646248180912
# accuracy(mean):  0.9528847589915561
# precision(mean):  0.9706975575504788
# recall(mean):  0.9124023214478619
# roc_auc(mean):  0.98375907603608
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# solver:  newton-cg
# f1_scores(mean):  0.9779938278556806
# accuracy(mean):  0.9821373897947028
# precision(mean):  0.9861554340054927
# recall(mean):  0.9699711215909035
# roc_auc(mean):  0.9978288190506543
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# solver:  lbfgs
# f1_scores(mean):  0.9779542017469387
# accuracy(mean):  0.9821045334862697
# precision(mean):  0.9860747253398363
# recall(mean):  0.9699711215909035
# roc_auc(mean):  0.997829903306874
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# solver:  sag
# f1_scores(mean):  0.9779938278556806
# accuracy(mean):  0.9821373897947028
# precision(mean):  0.9861554340054927
# recall(mean):  0.9699711215909035
# roc_auc(mean):  0.9978303075444103
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# solver:  newton-cg
# f1_scores(mean):  0.979155461482511
# accuracy(mean):  0.9830902095451627
# precision(mean):  0.9878804763612644
# recall(mean):  0.9705866995559459
# roc_auc(mean):  0.9979030768201287
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# solver:  lbfgs
# f1_scores(mean):  0.9791549354012339
# accuracy(mean):  0.9830902101448945
# precision(mean):  0.987907069573619
# recall(mean):  0.9705599365424307
# roc_auc(mean):  0.9979051929264685
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# solver:  sag
# f1_scores(mean):  0.979155461482511
# accuracy(mean):  0.9830902095451627
# precision(mean):  0.9878804763612644
# recall(mean):  0.9705866995559459
# roc_auc(mean):  0.9979053765361519
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.7
# solver:  newton-cg
# f1_scores(mean):  0.9911610235540982
# accuracy(mean):  0.9927607737910424
# precision(mean):  0.990435251300491
# recall(mean):  0.9918906206526221
# roc_auc(mean):  0.9992774330391635
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.7
# solver:  lbfgs
# f1_scores(mean):  0.9911340123590862
# accuracy(mean):  0.992738869785331
# precision(mean):  0.9904345971962544
# recall(mean):  0.9918370946255914
# roc_auc(mean):  0.9992787702286605
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.7
# solver:  sag
# f1_scores(mean):  0.9825050531385285
# accuracy(mean):  0.9857843866546447
# precision(mean):  0.9895521373378825
# recall(mean):  0.9755647454318772
# roc_auc(mean):  0.9991961699592169
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.8
# solver:  newton-cg
# f1_scores(mean):  0.9915220113800457
# accuracy(mean):  0.9930564739698902
# precision(mean):  0.9907816363553197
# recall(mean):  0.9922653171689315
# roc_auc(mean):  0.9993228557717645
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.8
# solver:  lbfgs
# f1_scores(mean):  0.9915087777155872
# accuracy(mean):  0.9930455222669003
# precision(mean):  0.9907551389116108
# recall(mean):  0.992265313587158
# roc_auc(mean):  0.999328916613511
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.8
# solver:  sag
# f1_scores(mean):  0.9833902835566084
# accuracy(mean):  0.9865072110466093
# precision(mean):  0.9906872667613822
# recall(mean):  0.9762070577562451
# roc_auc(mean):  0.999235568085377
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.9
# solver:  newton-cg
# f1_scores(mean):  0.9926338541442558
# accuracy(mean):  0.9939654911065137
# precision(mean):  0.9916406324163164
# recall(mean):  0.9936302666759506
# roc_auc(mean):  0.9994028032410203
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.9
# solver:  lbfgs
# f1_scores(mean):  0.9926742401681927
# accuracy(mean):  0.9939983468152149
# precision(mean):  0.9916414292498217
# recall(mean):  0.9937105557164966
# roc_auc(mean):  0.9993824773101249
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.9
# solver:  sag
# f1_scores(mean):  0.9811427883916737
# accuracy(mean):  0.9847110843774649
# precision(mean):  0.9904575348176341
# recall(mean):  0.9720051285269367
# roc_auc(mean):  0.9988174835138114
# -------------------------------------------------------------------------------------

# %%
# standardize ANOVA 0.9 newton-cg
final_pipline = Pipeline([
                         ('preprocess',StandardScaler()),
                         ('feature_selection',SelectPercentile(f_classif, percentile=90)),
                        ('estimator',LogisticRegression(solver ="newton-cg",max_iter=1000))
                    ])
final_pipline.fit(X_train,y_train)
y_test_pred = final_pipline.predict(X_test)

print(accuracy_score(y_test,y_test_pred))
print(recall_score(y_test,y_test_pred))
print(precision_score(y_test,y_test_pred))
print(roc_auc_score(y_test,y_test_pred))
print(f1_score(y_test,y_test_pred))
cnf_matrix = confusion_matrix(y_test, y_test_pred)
print("tn, fp, fn, tp:",  cnf_matrix.ravel())
# Out:
# 0.9936881915518871
# 0.9923235349185546
# 0.992261607588617
# 0.9934789461697924
# 0.9922925702873904
# tn, fp, fn, tp: [22986   124   123 15900]

# %% [markdown]
# ### SVM

# %%
# feature_selection_methods = ["PCA"]
# percentage_selections = [0.7,0.8,0.9]
# C_selections = [0.2,0.5,1,2,5]
SVM(X_train,y_train)
# Out:
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  0.2
# kernel_selection:  poly
# f1_scores(mean):  0.9785571379973345
# accuracy(mean):  0.9826959386418199
# precision(mean):  0.9925952295484951
# recall(mean):  0.9649127866744263
# roc_auc(mean):  0.9968319934609802
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  0.2
# kernel_selection:  rbf
# f1_scores(mean):  0.9871890249555124
# accuracy(mean):  0.989562795554219
# precision(mean):  0.9906806003558515
# recall(mean):  0.9837545714178466
# roc_auc(mean):  0.9983245132826513
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  0.2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8974566199397715
# accuracy(mean):  0.9156481441949158
# precision(mean):  0.8929534934801024
# recall(mean):  0.9020181181876454
# roc_auc(mean):  0.959373089178212
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  0.5
# kernel_selection:  poly
# f1_scores(mean):  0.9790551832274679
# accuracy(mean):  0.983101159448957
# precision(mean):  0.9933082286398335
# recall(mean):  0.9652071834048686
# roc_auc(mean):  0.9983323032233613
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  0.5
# kernel_selection:  rbf
# f1_scores(mean):  0.9918487971384625
# accuracy(mean):  0.9933193232378914
# precision(mean):  0.9904200995068593
# recall(mean):  0.9932823224278351
# roc_auc(mean):  0.9990725266334763
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  0.5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8918066019788077
# accuracy(mean):  0.9112345257267596
# precision(mean):  0.889653886645781
# recall(mean):  0.893989049371456
# roc_auc(mean):  0.9579485660646394
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  1
# kernel_selection:  poly
# f1_scores(mean):  0.979865671684123
# accuracy(mean):  0.9837582778211054
# precision(mean):  0.994324670133736
# recall(mean):  0.9658227434610422
# roc_auc(mean):  0.999054419008593
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  1
# kernel_selection:  rbf
# f1_scores(mean):  0.9927271177647687
# accuracy(mean):  0.9940421488293196
# precision(mean):  0.9917998293696721
# recall(mean):  0.9936570153623709
# roc_auc(mean):  0.9995135287301951
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  1
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8896684934104601
# accuracy(mean):  0.9095698314881295
# precision(mean):  0.8883985197158106
# recall(mean):  0.8909647572087496
# roc_auc(mean):  0.9574212756123675
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  2
# kernel_selection:  poly
# f1_scores(mean):  0.9810470839088502
# accuracy(mean):  0.9847110945729061
# precision(mean):  0.9955095670089408
# recall(mean):  0.9670003411281325
# roc_auc(mean):  0.9993037736196493
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  2
# kernel_selection:  rbf
# f1_scores(mean):  0.9938299928334468
# accuracy(mean):  0.9949511593688929
# precision(mean):  0.9939767508428327
# recall(mean):  0.9936837783758863
# roc_auc(mean):  0.9995480941641979
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8883611406488358
# accuracy(mean):  0.9085513015197307
# precision(mean):  0.887602749647888
# recall(mean):  0.8891448185631013
# roc_auc(mean):  0.9571173272248549
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  5
# kernel_selection:  poly
# f1_scores(mean):  0.9824137150648473
# accuracy(mean):  0.9858062906603564
# precision(mean):  0.9963672387152483
# recall(mean):  0.9688470392055224
# roc_auc(mean):  0.9994084946988769
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  5
# kernel_selection:  rbf
# f1_scores(mean):  0.994577547507534
# accuracy(mean):  0.9955644733280092
# precision(mean):  0.9950707902300054
# recall(mean):  0.9940852271603898
# roc_auc(mean):  0.9996013962918028
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.7
# C_selection:  5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8877610189082237
# accuracy(mean):  0.9080913179995218
# precision(mean):  0.8873105541328041
# recall(mean):  0.8882348438676164
# roc_auc(mean):  0.9569409699345961
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  0.2
# kernel_selection:  poly
# f1_scores(mean):  0.9782550972375438
# accuracy(mean):  0.9824549963781894
# precision(mean):  0.9924551842842126
# recall(mean):  0.9644577975357971
# roc_auc(mean):  0.9960653723649584
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  0.2
# kernel_selection:  rbf
# f1_scores(mean):  0.9810763058101305
# accuracy(mean):  0.9846453771581851
# precision(mean):  0.9896290465360668
# recall(mean):  0.9726742468461052
# roc_auc(mean):  0.9980412209316996
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  0.2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.9077201354337268
# accuracy(mean):  0.924267295775763
# precision(mean):  0.9052442435996774
# recall(mean):  0.9102344779536095
# roc_auc(mean):  0.9602682350590748
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  0.5
# kernel_selection:  poly
# f1_scores(mean):  0.9788148775689702
# accuracy(mean):  0.982904023397554
# precision(mean):  0.9928708056553678
# recall(mean):  0.965153657377838
# roc_auc(mean):  0.9977353882423359
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  0.5
# kernel_selection:  rbf
# f1_scores(mean):  0.9915576021169427
# accuracy(mean):  0.9930783797747971
# precision(mean):  0.9898133125703208
# recall(mean):  0.9933090890231242
# roc_auc(mean):  0.9985904750066121
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  0.5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.900276415281612
# accuracy(mean):  0.9181999389700893
# precision(mean):  0.8982928432574291
# recall(mean):  0.9022857519045724
# roc_auc(mean):  0.9579546307272138
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  1
# kernel_selection:  poly
# f1_scores(mean):  0.9793803110987651
# accuracy(mean):  0.9833640069177628
# precision(mean):  0.9936658324640273
# recall(mean):  0.9655015801353107
# roc_auc(mean):  0.9986691632901833
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  1
# kernel_selection:  rbf
# f1_scores(mean):  0.9922872704768821
# accuracy(mean):  0.9936807354338736
# precision(mean):  0.9911887874911244
# recall(mean):  0.9933893852272178
# roc_auc(mean):  0.9994349608159672
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  1
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8971734935605407
# accuracy(mean):  0.9157028943136194
# precision(mean):  0.8956942405906083
# recall(mean):  0.8986726626992075
# roc_auc(mean):  0.9570545660517975
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  2
# kernel_selection:  poly
# f1_scores(mean):  0.9802302829247257
# accuracy(mean):  0.9840539774002215
# precision(mean):  0.994792260210876
# recall(mean):  0.9660903771779692
# roc_auc(mean):  0.9991291452292946
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  2
# kernel_selection:  rbf
# f1_scores(mean):  0.9934176683041451
# accuracy(mean):  0.9946116487796948
# precision(mean):  0.9931789612050395
# recall(mean):  0.9936570117805971
# roc_auc(mean):  0.9995261206520295
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8954386048451342
# accuracy(mean):  0.9143339116487418
# precision(mean):  0.8945218059083665
# recall(mean):  0.8963710041373785
# roc_auc(mean):  0.9566189548918921
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  5
# kernel_selection:  poly
# f1_scores(mean):  0.9819873466358535
# accuracy(mean):  0.9854667824700856
# precision(mean):  0.9962545473678812
# recall(mean):  0.9681244306770612
# roc_auc(mean):  0.9993190793609085
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  5
# kernel_selection:  rbf
# f1_scores(mean):  0.9944166038949689
# accuracy(mean):  0.995433046894813
# precision(mean):  0.9949630855519492
# recall(mean):  0.9938711194704934
# roc_auc(mean):  0.9995473442767379
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.8
# C_selection:  5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.9007948633731232
# accuracy(mean):  0.9187036261483822
# precision(mean):  0.8998251726377635
# recall(mean):  0.9017771077950572
# roc_auc(mean):  0.9556404855919574
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  0.2
# kernel_selection:  poly
# f1_scores(mean):  0.9775974045716203
# accuracy(mean):  0.9819402561422269
# precision(mean):  0.9926907061007674
# recall(mean):  0.9629590437065225
# roc_auc(mean):  0.9960965723722138
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  0.2
# kernel_selection:  rbf
# f1_scores(mean):  0.9806419949630095
# accuracy(mean):  0.984294915465729
# precision(mean):  0.9893256792262349
# recall(mean):  0.972112198489867
# roc_auc(mean):  0.9978039137873733
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  0.2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.9369305934447093
# accuracy(mean):  0.9485367925673506
# precision(mean):  0.9397598002585029
# recall(mean):  0.9341344937420681
# roc_auc(mean):  0.9579256190509751
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  0.5
# kernel_selection:  poly
# f1_scores(mean):  0.9788002846566201
# accuracy(mean):  0.9828930728940278
# precision(mean):  0.9928971609553157
# recall(mean):  0.9651001313508072
# roc_auc(mean):  0.9974070332045658
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  0.5
# kernel_selection:  rbf
# f1_scores(mean):  0.9916784028143653
# accuracy(mean):  0.9931769439022418
# precision(mean):  0.9898678762569487
# recall(mean):  0.9934964336995051
# roc_auc(mean):  0.9985769553785222
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  0.5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.928654115619155
# accuracy(mean):  0.9416808663673274
# precision(mean):  0.9297995349361241
# recall(mean):  0.9275238144973581
# roc_auc(mean):  0.9549203728466343
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  1
# kernel_selection:  poly
# f1_scores(mean):  0.9791868744525732
# accuracy(mean):  0.9832106800772463
# precision(mean):  0.9936365079484825
# recall(mean):  0.965153657377838
# roc_auc(mean):  0.9983310718626603
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  1
# kernel_selection:  rbf
# f1_scores(mean):  0.9923939093405542
# accuracy(mean):  0.9937683526561832
# precision(mean):  0.9913212502293746
# recall(mean):  0.9934696742677638
# roc_auc(mean):  0.9994044742240046
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  1
# kernel_selection:  sigmoid
# f1_scores(mean):  0.925289116607971
# accuracy(mean):  0.9388443033251453
# precision(mean):  0.92515005816091
# recall(mean):  0.9254362063170454
# roc_auc(mean):  0.9535231942584046
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  2
# kernel_selection:  poly
# f1_scores(mean):  0.9800522871713764
# accuracy(mean):  0.9839116046616219
# precision(mean):  0.9946808111369918
# recall(mean):  0.9658495100563312
# roc_auc(mean):  0.9989452203845521
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  2
# kernel_selection:  rbf
# f1_scores(mean):  0.9934844448112019
# accuracy(mean):  0.9946664078943757
# precision(mean):  0.9932588407234053
# recall(mean):  0.9937105413894016
# roc_auc(mean):  0.9995488070694469
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.9227779536869705
# accuracy(mean):  0.936730582067151
# precision(mean):  0.9217606600484833
# recall(mean):  0.9238035836935883
# roc_auc(mean):  0.9546057665884871
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  5
# kernel_selection:  poly
# f1_scores(mean):  0.9815919140303457
# accuracy(mean):  0.9851491764863308
# precision(mean):  0.995950534869445
# recall(mean):  0.9676426785249166
# roc_auc(mean):  0.9992777130060139
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  5
# kernel_selection:  rbf
# f1_scores(mean):  0.9943898554833396
# accuracy(mean):  0.9954111452880291
# precision(mean):  0.9949362516171183
# recall(mean):  0.9938443564569782
# roc_auc(mean):  0.9995867780386763
# -------------------------------------------------------------------------------------
# preprocess:  standardize
# feature_selection:  PCA
# percentage_selection:  0.9
# C_selection:  5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.9208764987365339
# accuracy(mean):  0.9351863601598
# precision(mean):  0.9200447406362683
# recall(mean):  0.9217160220763342
# roc_auc(mean):  0.9542271156560524
# -------------------------------------------------------------------------------------

# %%
#     feature_selection_methods = ["ANOVA"]
#     percentage_selections = [0.1,0.3,0.5]
#     C_selections = [0.2,0.5,1,2,5]
#     kernel_selections = ['poly','rbf','sigmoid']
SVM(X_train,y_train)
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  0.2
# kernel_selection:  poly
# f1_scores(mean):  0.9542186867609439
# accuracy(mean):  0.9638914543917345
# precision(mean):  0.9915780298546137
# recall(mean):  0.9195750597941311
# roc_auc(mean):  0.9900751062759683
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  0.2
# kernel_selection:  rbf
# f1_scores(mean):  0.9546698561405986
# accuracy(mean):  0.9641652565621893
# precision(mean):  0.9895746713763364
# recall(mean):  0.9221443663999821
# roc_auc(mean):  0.9912401495028809
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  0.2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8969786013195773
# accuracy(mean):  0.9154072109272627
# precision(mean):  0.8940342967955754
# recall(mean):  0.8999572730208479
# roc_auc(mean):  0.9635563190281294
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  0.5
# kernel_selection:  poly
# f1_scores(mean):  0.9559552056355789
# accuracy(mean):  0.9652385582396376
# precision(mean):  0.9927208698879367
# recall(mean):  0.921823246055536
# roc_auc(mean):  0.990926556722658
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  0.5
# kernel_selection:  rbf
# f1_scores(mean):  0.9598259680073907
# accuracy(mean):  0.9680860537933906
# precision(mean):  0.9897655982519413
# recall(mean):  0.9316454869220843
# roc_auc(mean):  0.9921382200187742
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  0.5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8911713798380028
# accuracy(mean):  0.9108183442206552
# precision(mean):  0.8900292806688608
# recall(mean):  0.8923295849354608
# roc_auc(mean):  0.9628584115959378
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  1
# kernel_selection:  poly
# f1_scores(mean):  0.9614098752955268
# accuracy(mean):  0.9694441039466966
# precision(mean):  0.9949125474758619
# recall(mean):  0.9300931927386843
# roc_auc(mean):  0.9919572115792544
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  1
# kernel_selection:  rbf
# f1_scores(mean):  0.962466476223149
# accuracy(mean):  0.970254547360166
# precision(mean):  0.9950641025352777
# recall(mean):  0.9319398836525267
# roc_auc(mean):  0.9927418805573576
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  1
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8893557182759662
# accuracy(mean):  0.909383636344543
# precision(mean):  0.8887259301262154
# recall(mean):  0.8900011741054377
# roc_auc(mean):  0.9625919632281347
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  2
# kernel_selection:  poly
# f1_scores(mean):  0.9625810840373982
# accuracy(mean):  0.9703750028989537
# precision(mean):  0.9961644449605502
# recall(mean):  0.9311904870381339
# roc_auc(mean):  0.9925389915298475
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  2
# kernel_selection:  rbf
# f1_scores(mean):  0.9633229166275644
# accuracy(mean):  0.9709554515536596
# precision(mean):  0.9966815333000948
# recall(mean):  0.9321272068382653
# roc_auc(mean):  0.9934097448400256
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8880423937834749
# accuracy(mean):  0.9083322524666386
# precision(mean):  0.887652133865838
# recall(mean):  0.8884488763402638
# roc_auc(mean):  0.9624482115838229
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  5
# kernel_selection:  poly
# f1_scores(mean):  0.9634073795975775
# accuracy(mean):  0.9710211629710621
# precision(mean):  0.9967099900768485
# recall(mean):  0.9322610254876155
# roc_auc(mean):  0.9939130055327855
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  5
# kernel_selection:  rbf
# f1_scores(mean):  0.9642191344242569
# accuracy(mean):  0.9716454280334366
# precision(mean):  0.996857353938051
# recall(mean):  0.9336527451716974
# roc_auc(mean):  0.9939376640907206
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.1
# C_selection:  5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8872125432012954
# accuracy(mean):  0.9076751376928811
# precision(mean):  0.8870347357543447
# recall(mean):  0.8874050758318812
# roc_auc(mean):  0.9623593703306774
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  0.2
# kernel_selection:  poly
# f1_scores(mean):  0.9795701102549941
# accuracy(mean):  0.9835720958716194
# precision(mean):  0.9972550449432898
# recall(mean):  0.9625039972595133
# roc_auc(mean):  0.998999540183269
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  0.2
# kernel_selection:  rbf
# f1_scores(mean):  0.9855496989186904
# accuracy(mean):  0.9882923728186637
# precision(mean):  0.9956044800225907
# recall(mean):  0.9756985175181688
# roc_auc(mean):  0.9992223939027227
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  0.2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8871891864081352
# accuracy(mean):  0.907324654410079
# precision(mean):  0.8838732348670101
# recall(mean):  0.8905364093033278
# roc_auc(mean):  0.9596467651564545
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  0.5
# kernel_selection:  poly
# f1_scores(mean):  0.9854740254211174
# accuracy(mean):  0.9882485696050953
# precision(mean):  0.9970693497809359
# recall(mean):  0.9741462591525064
# roc_auc(mean):  0.9991079286941764
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  0.5
# kernel_selection:  rbf
# f1_scores(mean):  0.9879048357022231
# accuracy(mean):  0.9901761083138719
# precision(mean):  0.9954894401134246
# recall(mean):  0.9804357105995575
# roc_auc(mean):  0.9994184053161101
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  0.5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8825482260360756
# accuracy(mean):  0.9037543212702612
# precision(mean):  0.8814486685803761
# recall(mean):  0.8836581572318447
# roc_auc(mean):  0.9592392276502562
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  1
# kernel_selection:  poly
# f1_scores(mean):  0.9875931360820855
# accuracy(mean):  0.9899461171534993
# precision(mean):  0.9975161367361313
# recall(mean):  0.9778664039937063
# roc_auc(mean):  0.9991888171139205
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  1
# kernel_selection:  rbf
# f1_scores(mean):  0.9891926601700298
# accuracy(mean):  0.991216542887714
# precision(mean):  0.9961192580001639
# recall(mean):  0.9823626905539458
# roc_auc(mean):  0.9995371319317907
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  1
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8810132182291277
# accuracy(mean):  0.9025605610553665
# precision(mean):  0.8804929516347993
# recall(mean):  0.8815438469281706
# roc_auc(mean):  0.9590345664770542
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  2
# kernel_selection:  poly
# f1_scores(mean):  0.988467463526128
# accuracy(mean):  0.9906470429373387
# precision(mean):  0.9975745868449952
# recall(mean):  0.9795257573947153
# roc_auc(mean):  0.9993148812040316
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  2
# kernel_selection:  rbf
# f1_scores(mean):  0.9897213209946443
# accuracy(mean):  0.9916436706992215
# precision(mean):  0.99633825644087
# recall(mean):  0.9831923762088846
# roc_auc(mean):  0.9996423673145065
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.8802611052054379
# accuracy(mean):  0.9019801046041467
# precision(mean):  0.8800587565639122
# recall(mean):  0.8804732941515938
# roc_auc(mean):  0.9589480351207363
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  5
# kernel_selection:  poly
# f1_scores(mean):  0.989723300914511
# accuracy(mean):  0.9916546200032841
# precision(mean):  0.9974992355428534
# recall(mean):  0.9820682902417296
# roc_auc(mean):  0.9994408628105113
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  5
# kernel_selection:  rbf
# f1_scores(mean):  0.9902507341360369
# accuracy(mean):  0.9920707931131426
# precision(mean):  0.9964768405255289
# recall(mean):  0.984102340159048
# roc_auc(mean):  0.9997023709195559
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.3
# C_selection:  5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.879822386123774
# accuracy(mean):  0.9016405976133395
# precision(mean):  0.8797974861880684
# recall(mean):  0.8798577340954201
# roc_auc(mean):  0.958890182685578
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  0.2
# kernel_selection:  poly
# f1_scores(mean):  0.9827656382169356
# accuracy(mean):  0.98608008923242
# precision(mean):  0.9959883531093933
# recall(mean):  0.9698908182232625
# roc_auc(mean):  0.9986223211433558
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  0.2
# kernel_selection:  rbf
# f1_scores(mean):  0.9833963395727139
# accuracy(mean):  0.986561967762363
# precision(mean):  0.9945280303470685
# recall(mean):  0.9725136580196917
# roc_auc(mean):  0.9989776495200335
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  0.2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.923798620419593
# accuracy(mean):  0.9369934763150397
# precision(mean):  0.9144967304224327
# recall(mean):  0.9333048367413195
# roc_auc(mean):  0.9743586977890433
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  0.5
# kernel_selection:  poly
# f1_scores(mean):  0.9837564836661817
# accuracy(mean):  0.9868795815426316
# precision(mean):  0.9969229400743858
# recall(mean):  0.9709345972410025
# roc_auc(mean):  0.9990327292464162
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  0.5
# kernel_selection:  rbf
# f1_scores(mean):  0.9867730305573097
# accuracy(mean):  0.989267099573494
# precision(mean):  0.9952908898106045
# recall(mean):  0.9784016857546554
# roc_auc(mean):  0.9992759894568908
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  0.5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.9158519648481706
# accuracy(mean):  0.9306741883593718
# precision(mean):  0.9098423436596674
# recall(mean):  0.9219570288871486
# roc_auc(mean):  0.9728886303599154
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  1
# kernel_selection:  poly
# f1_scores(mean):  0.984744218917639
# accuracy(mean):  0.9876681185514622
# precision(mean):  0.9971193095472202
# recall(mean):  0.972674214610141
# roc_auc(mean):  0.9991934577977478
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  1
# kernel_selection:  rbf
# f1_scores(mean):  0.9879095524822539
# accuracy(mean):  0.990176111312531
# precision(mean):  0.995085383947532
# recall(mean):  0.9808371737111561
# roc_auc(mean):  0.9993775860589904
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  1
# kernel_selection:  sigmoid
# f1_scores(mean):  0.9113336194728408
# accuracy(mean):  0.9271805111431644
# precision(mean):  0.9081640275419132
# recall(mean):  0.9145434341645629
# roc_auc(mean):  0.9723323193425276
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  2
# kernel_selection:  poly
# f1_scores(mean):  0.9865720169871806
# accuracy(mean):  0.989124726235163
# precision(mean):  0.9970482441691854
# recall(mean):  0.9763141169738538
# roc_auc(mean):  0.9992656696371697
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  2
# kernel_selection:  rbf
# f1_scores(mean):  0.9890593372769023
# accuracy(mean):  0.9911070234588886
# precision(mean):  0.9958487244649623
# recall(mean):  0.9823626905539455
# roc_auc(mean):  0.99948370427574
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  2
# kernel_selection:  sigmoid
# f1_scores(mean):  0.9086005936460886
# accuracy(mean):  0.9250558375824485
# precision(mean):  0.9068836630962078
# recall(mean):  0.9103415371712182
# roc_auc(mean):  0.9720380359566928
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  5
# kernel_selection:  poly
# f1_scores(mean):  0.9882477931974696
# accuracy(mean):  0.9904718108916469
# precision(mean):  0.9976548920725147
# recall(mean):  0.9790172493926029
# roc_auc(mean):  0.9993661557284463
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  5
# kernel_selection:  rbf
# f1_scores(mean):  0.9898026934399438
# accuracy(mean):  0.9917093803174286
# precision(mean):  0.9963657798103341
# recall(mean):  0.9833261876946875
# roc_auc(mean):  0.9995794958486768
# -------------------------------------------------------------------------------------
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]preprocess:  standardize
# feature_selection:  ANOVA
# percentage_selection:  0.5
# C_selection:  5
# kernel_selection:  sigmoid
# f1_scores(mean):  0.90656073364263
# accuracy(mean):  0.9234787593666642
# precision(mean):  0.9059791099515255
# recall(mean):  0.9071566526003249
# roc_auc(mean):  0.9718438688879196
# -------------------------------------------------------------------------------------

# %%
# standardize PCA 0.9 2 rbf
final_pipline = Pipeline([
                         ('preprocess',StandardScaler()),
                         ('feature_selection',PCA(n_components=0.9)),
                        ('estimator',SVC(C=2, kernel="rbf",verbose = True))
                    ])
final_pipline.fit(X_train,y_train)
y_test_pred = final_pipline.predict(X_test)

print(accuracy_score(y_test,y_test_pred))
print(recall_score(y_test,y_test_pred))
print(precision_score(y_test,y_test_pred))
print(roc_auc_score(y_test,y_test_pred))
print(f1_score(y_test,y_test_pred))
cnf_matrix = confusion_matrix(y_test, y_test_pred)
print("tn, fp, fn, tp:",  cnf_matrix.ravel())
# Out:
# [LibSVM]0.9947614545268699
# 0.9930724583411347
# 0.9941272022991379
# 0.9945024775478931
# 0.9935995504074432
# tn, fp, fn, tp: [23016    94   111 15912]
